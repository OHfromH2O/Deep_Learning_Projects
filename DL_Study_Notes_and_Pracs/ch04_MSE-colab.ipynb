# %% [markdown]
# # 4장. 가장 훌륭한 예측선

# %% [markdown]
# ## 4. 파이썬 코딩으로 확인하는 최소 제곱
# 1.1.)선형 회귀는 해당 데이터셋을 가장 잘 설명하는 직선을 찾아내는 것이다.
#
# 1.2.)최적의 기울기와 y절편값을 찾아내는 것이다.
#
# 1.3.)머신러닝의 에측이란. 기존 데이터를 가지고 어떤 선이 그려질 지 예측한 후, 아직 답이 나오지 않은 무언가에 그 선을 대입해보는 것이다.
#
#
#
# ---
#
#
# 2.1.)주어진 정보를 바탕으로 최적의 기울기를 구하는 공식 =** 최소 제곱법**
# : x의 편차 (각 값과 평균과의 차이)를 제곱한 값을 분모에 놓고, x/y의 편차를 곱하여 합한 값을 분자로 놓으면 그것이 기울기가 된다.
#
# 2.2.)즉, 오차가 가장 적으면서, 주어진 좌표의 특성을 가장 잘 잡아내는 직선의 기울기를 구한 것이다.
#
#
# ---
#
#
#
# 3.1.)이렇게 구해진 최적의 기울기에서 y절편 b를 유추해낼 수 있다: b = my- (mx*a)

# %% [markdown]
# ### 1. 환경 준비

# %%
import numpy as np

# %% [markdown]
# ### 2. 데이터 준비

# %%
# 공부한 시간과 점수를 각각 x, y라는 이름의 넘파이 배열로 만듭니다. (시리즈)
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# 파이썬 리스트 [대괄호]를 넘파이 어레이 (배열)로 바꾸는 것이다.

# %% [markdown]
# #### [x와 y의 평균값]

# %%
#x의 평균값을 구합니다.
mx = np.mean(x)

#y의 평균값을 구합니다.
my = np.mean(y)

# 출력으로 확인합니다.
print("x의 평균값:", mx)
print("y의 평균값:", my)
# Out:
# x의 평균값: 5.0
# y의 평균값: 90.5

# %% [markdown]
# #### [기울기 공식의 분모와 분자]

# %%
# 기울기 공식의 분모 부분입니다.
divisor = sum([(i - mx)**2 for i in x])

# 기울기 공식의 분자 부분입니다.
def top(x, mx, y, my):
    d = 0
    for i in range(len(x)):
        d += (x[i] - mx) * (y[i] - my)
    return d
dividend = top(x, mx, y, my)

# 출력으로 확인합니다.
print("분모:", divisor)
print("분자:", dividend)
# Out:
# 분모: 20.0
# 분자: 46.0

# %% [markdown]
# ### 3. 기울기와 y 절편 구하기

# %%
# 기울기 a를 구하는 공식입니다.
a = dividend / divisor

# y 절편 b를 구하는 공식입니다.
b = my - (mx*a)

# 출력으로 확인합니다.
print("기울기 a =", a)
print("y절편 b =", b)
# Out:
# 기울기 a = 2.3
# y절편 b = 79.0

# %% [markdown]
# ## 6. 파이썬 코딩으로 확인하는 평균 제곱 오차

# %% [markdown]
# 1.1.)만약 최소제곱법을 사용하지 않고, 랜덤한 값을 a,b에 할당한다면?
# 1.2.)이 값을 바탕으로 오차를 구하고, 이 오차를 최소하는 방식으로 우리는 최적의 직선을 찾을 수 있다.
#
# 2.1.) 오차 = 실제 값 - 예측값이다. 단순히 더해버리면 합이 0이 될 수 있으므로 제곱을 한다. 이러한 오차 제곱의 합을 n으로 나누면, 그것이 평균 제곱 오차이다.

# %% [markdown]
# ### 1. 환경 준비

# %%
import numpy as np

# %% [markdown]
# ### 2. 데이터 준비

# %%
# 가상의 기울기 a와 y 절편 b를 정합니다.
fake_a=3
fake_b=76

# 공부 시간 x와 성적 y의 넘파이 배열을 만듭니다.
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# ### 3. 평균 제곱 오차 구하기

# %%
# y=ax + b에 가상의 a,b 값을 대입한 결과를 출력하는 함수입니다.
def predict(x):
    return fake_a * x + fake_b

# 예측 값이 들어갈 빈 리스트를 만듭니다.
predict_result = []

# 모든 x 값을 한 번씩 대입하여 predict_result 리스트를 완성합니다.
for i in range(len(x)):
    predict_result.append(predict(x[i]))
    print("공부시간=%.f, 실제점수=%.f, 예측점수=%.f" % (x[i], y[i], predict(x[i])))
# Out:
# 공부시간=2, 실제점수=81, 예측점수=82
# 공부시간=4, 실제점수=93, 예측점수=88
# 공부시간=6, 실제점수=91, 예측점수=94
# 공부시간=8, 실제점수=97, 예측점수=100

# %%
# 평균 제곱 오차 함수를 각 y 값에 대입하여 최종 값을 구하는 함수입니다.
n=len(x)
def mse(y, y_pred):
    return (1/n) * sum((y - y_pred)**2)

# 평균 제곱 오차 값을 출력합니다.
print("평균 제곱 오차: " + str(mse(y,predict_result)))
# Out:
# 평균 제곱 오차: 11.0
